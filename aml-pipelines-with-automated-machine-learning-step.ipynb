# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-127085
# aml-quickstarts-127085
# southcentralus
# ef22e2eb-a072-4db6-86df-7ea6643b1b5f

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'udacity-project'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: udacity-project,
# Workspace: quick-starts-ws-127085)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-Marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#            age  duration  campaign    pdays  previous  emp.var.rate  \
# count 32950.00  32950.00  32950.00 32950.00  32950.00      32950.00
# mean     40.04    257.34      2.56   962.17      0.17          0.08
# std      10.43    257.33      2.76   187.65      0.50          1.57
# min      17.00      0.00      1.00     0.00      0.00         -3.40
# 25%      32.00    102.00      1.00   999.00      0.00         -1.80
# 50%      38.00    179.00      2.00   999.00      0.00          1.10
# 75%      47.00    318.00      3.00   999.00      0.00          1.40
# max      98.00   4918.00     56.00   999.00      7.00          1.40
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# count        32950.00       32950.00   32950.00     32950.00
# mean            93.57         -40.52       3.62      5166.86
# std              0.58           4.62       1.74        72.21
# min             92.20         -50.80       0.63      4963.60
# 25%             93.08         -42.70       1.34      5099.10
# 50%             93.75         -41.80       4.86      5191.00
# 75%             93.99         -36.40       4.96      5228.10
# max             94.77         -26.90       5.04      5228.10

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure        -1.80
# 1   may         thu  ...         2    999         0  nonexistent         1.10
# 2   may         fri  ...         1    999         1      failure        -1.80
# 3   jun         fri  ...         4    999         0  nonexistent         1.40
# 4   jul         fri  ...         2    999         0  nonexistent         1.40
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           92.89         -46.20       1.30      5099.10  no
# 1           93.99         -36.40       4.86      5191.00  no
# 2           92.89         -46.20       1.31      5099.10  no
# 3           94.47         -41.80       4.97      5228.10  no
# 4           93.92         -42.70       4.96      5228.10  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [2d9b661f][9b87f56f-b3a6-4ac6-84d3-dc4ce946c412], (This step will run and generate new outputs)
# Submitted PipelineRun 71d88d64-9430-458e-bc2a-31b5f429c8d1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/71d88d64-9430-458e-bc2a-31b5f429c8d1?wsid=/subscriptions/ef22e2eb-a072-4db6-86df-7ea6643b1b5f/resourcegroups/aml-quickstarts-127085/workspaces/quick-starts-ws-127085

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 71d88d64-9430-458e-bc2a-31b5f429c8d1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/71d88d64-9430-458e-bc2a-31b5f429c8d1?wsid=/subscriptions/ef22e2eb-a072-4db6-86df-7ea6643b1b5f/resourcegroups/aml-quickstarts-127085/workspaces/quick-starts-ws-127085
# PipelineRun Status: Running
#
#
# StepRunId: 790bdf3f-6cde-4992-babe-0f0b16f9fb95
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/790bdf3f-6cde-4992-babe-0f0b16f9fb95?wsid=/subscriptions/ef22e2eb-a072-4db6-86df-7ea6643b1b5f/resourcegroups/aml-quickstarts-127085/workspaces/quick-starts-ws-127085
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '790bdf3f-6cde-4992-babe-0f0b16f9fb95', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2020-11-21T05:49:30.239476Z', 'endTimeUtc': '2020-11-21T06:12:30.851762Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '96265aba-1e36-4639-9d6a-ed9cf619b95c', 'StepType': 'AutoMLStep', 'azureml.moduleid': '9b87f56f-b3a6-4ac6-84d3-dc4ce946c412', 'azureml.nodeid': '2d9b661f', 'azureml.pipelinerunid': '71d88d64-9430-458e-bc2a-31b5f429c8d1', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "ef22e2eb-a072-4db6-86df-7ea6643b1b5f", "resource_group": "aml-quickstarts-127085", "workspace_name": "quick-starts-ws-127085", "region": "southcentralus", "compute_target": "auto-ml", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["DecisionTree", "LogisticRegression", "RandomForest", "ExtremeRandomTrees", "LightGBM", "KNN", "SVM", "SGD", "BernoulliNaiveBayes", "TensorFlowLinearClassifier", "AveragedPerceptronClassifier", "LinearSVM", "TensorFlowDNN", "XGBoostClassifier", "GradientBoosting", "MultinomialNaiveBayes"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"8ae406f8-b8b3-46fa-9c97-766c8eeed642\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '96265aba-1e36-4639-9d6a-ed9cf619b95c', 'SetupRunId': '790bdf3f-6cde-4992-babe-0f0b16f9fb95_setup', 'SetupRunContainerId': 'dcid.790bdf3f-6cde-4992-babe-0f0b16f9fb95_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '790bdf3f-6cde-4992-babe-0f0b16f9fb95_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classe ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '71d88d64-9430-458e-bc2a-31b5f429c8d1', 'status': 'Completed', 'startTimeUtc': '2020-11-21T05:48:55.508774Z', 'endTimeUtc': '2020-11-21T06:14:06.148903Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg127085.blob.core.windows.net/azureml/ExperimentRun/dcid.71d88d64-9430-458e-bc2a-31b5f429c8d1/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=WK9oLKncWBoKIs8JqlSCeSUA0Wyl0UAVTF%2FVcYxyHeA%3D&st=2020-11-21T05%3A39%3A20Z&se=2020-11-21T13%3A49%3A20Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg127085.blob.core.windows.net/azureml/ExperimentRun/dcid.71d88d64-9430-458e-bc2a-31b5f429c8d1/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=NQ34xkxkMngXxRGTMosBSU3lMLgyQp9Lh4GXtfFNf1Y%3D&st=2020-11-21T05%3A39%3A20Z&se=2020-11-21T13%3A49%3A20Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg127085.blob.core.windows.net/azureml/ExperimentRun/dcid.71d88d64-9430-458e-bc2a-31b5f429c8d1/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=PbzjKpsD7R%2F13g%2FbPllSuQlWYFeyii7feofJ0pv5tLg%3D&st=2020-11-21T05%3A39%3A20Z&se=2020-11-21T13%3A49%3A20Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/790bdf3f-6cde-4992-babe-0f0b16f9fb95/metrics_data
# Downloaded azureml/790bdf3f-6cde-4992-babe-0f0b16f9fb95/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_30  \
# f1_score_weighted                                   [0.8989534638286876]
# f1_score_micro                                      [0.9062215477996965]
# f1_score_macro                                      [0.7284535490225417]
# norm_macro_recall                                   [0.3994279860775367]
# AUC_macro                                           [0.9321891202507377]
# accuracy                                            [0.9062215477996965]
# balanced_accuracy                                   [0.6997139930387684]
# average_precision_score_weighted                    [0.9476121897815969]
# average_precision_score_macro                       [0.7965605392729129]
# precision_score_macro                               [0.7732606767203143]
# precision_score_micro                               [0.9062215477996965]
# log_loss                                           [0.19851273585356463]
# average_precision_score_micro                       [0.9773869264912682]
# AUC_weighted                                        [0.9321891202507377]
# recall_score_macro                                  [0.6997139930387684]
# AUC_micro                                            [0.976266150257552]
# recall_score_micro                                  [0.9062215477996965]
# recall_score_weighted                               [0.9062215477996965]
# precision_score_weighted                            [0.8957763334230099]
# weighted_accuracy                                   [0.9574917877119957]
# matthews_correlation                                [0.4672214930342567]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_37  \
# f1_score_weighted                                   [0.9091603275553164]
# f1_score_micro                                        [0.91350531107739]
# f1_score_macro                                      [0.7610253560094269]
# norm_macro_recall                                  [0.47630995448710456]
# AUC_macro                                           [0.9443518256098486]
# accuracy                                              [0.91350531107739]
# balanced_accuracy                                   [0.7381549772435523]
# average_precision_score_weighted                    [0.9528812754593075]
# average_precision_score_macro                       [0.8142566687071048]
# precision_score_macro                               [0.7914385680963489]
# precision_score_micro                                 [0.91350531107739]
# log_loss                                           [0.18416061132957412]
# average_precision_score_micro                       [0.9805171046193448]
# AUC_weighted                                        [0.9443518256098486]
# recall_score_macro                                  [0.7381549772435523]
# AUC_micro                                           [0.9795687124235231]
# recall_score_micro                                    [0.91350531107739]
# recall_score_weighted                                 [0.91350531107739]
# precision_score_weighted                            [0.9067413615217357]
# weighted_accuracy                                   [0.9570400558220584]
# matthews_correlation                                [0.5269062366413191]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_24  \
# f1_score_weighted                                   [0.9089184662494058]
# f1_score_micro                                      [0.9122913505311078]
# f1_score_macro                                      [0.7627410915322497]
# norm_macro_recall                                  [0.48915248209214823]
# AUC_macro                                            [0.945970802838582]
# accuracy                                            [0.9122913505311078]
# balanced_accuracy                                   [0.7445762410460741]
# average_precision_score_weighted                     [0.954332087539875]
# average_precision_score_macro                       [0.8200326992673153]
# precision_score_macro                                [0.785370400389042]
# precision_score_micro                               [0.9122913505311078]
# log_loss                                           [0.17893565105766665]
# average_precision_score_micro                       [0.9809180067615155]
# AUC_weighted                                        [0.9459708028385821]
# recall_score_macro                                  [0.7445762410460741]
# AUC_micro                                           [0.9800006907969725]
# recall_score_micro                                  [0.9122913505311078]
# recall_score_weighted                               [0.9122913505311078]
# precision_score_weighted                            [0.9066925945996073]
# weighted_accuracy                                   [0.9539304755992922]
# matthews_correlation                                [0.5283741849597311]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_11  \
# f1_score_weighted                                   [0.8767483425855039]
# f1_score_micro                                       [0.858877086494689]
# f1_score_macro                                      [0.7419495171453445]
# norm_macro_recall                                   [0.6918793658203157]
# AUC_macro                                            [0.923057366253772]
# accuracy                                             [0.858877086494689]
# balanced_accuracy                                   [0.8459396829101579]
# average_precision_score_weighted                    [0.9376091628384801]
# average_precision_score_macro                       [0.7566513658745583]
# precision_score_macro                               [0.7039254289701441]
# precision_score_micro                                [0.858877086494689]
# log_loss                                            [0.7881686774460037]
# average_precision_score_micro                       [0.9118662137255992]
# AUC_weighted                                         [0.923057366253772]
# recall_score_macro                                  [0.8459396829101579]
# AUC_micro                                           [0.9228152279284612]
# recall_score_micro                                   [0.858877086494689]
# recall_score_weighted                                [0.858877086494689]
# precision_score_weighted                            [0.9147883285392027]
# weighted_accuracy                                   [0.8620890938538823]
# matthews_correlation                                [0.5312095565226573]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_18  \
# f1_score_weighted                                   [0.8688265418012137]
# f1_score_micro                                      [0.8500758725341426]
# f1_score_macro                                      [0.7244125016930787]
# norm_macro_recall                                   [0.6393394795191971]
# AUC_macro                                           [0.9062891893443883]
# accuracy                                            [0.8500758725341426]
# balanced_accuracy                                   [0.8196697397595986]
# average_precision_score_weighted                    [0.9360140811202199]
# average_precision_score_macro                       [0.7600803354777432]
# precision_score_macro                               [0.6898078744210551]
# precision_score_micro                               [0.8500758725341426]
# log_loss                                           [0.40151812063389136]
# average_precision_score_micro                       [0.8900849932807828]
# AUC_weighted                                        [0.9062891893443884]
# recall_score_macro                                  [0.8196697397595986]
# AUC_micro                                           [0.9103643954029764]
# recall_score_micro                                  [0.8500758725341426]
# recall_score_weighted                               [0.8500758725341426]
# precision_score_weighted                            [0.9062924339430649]
# weighted_accuracy                                   [0.8576248928300871]
# matthews_correlation                               [0.49264930252869027]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_16  \
# f1_score_weighted                                   [0.7578630254586425]
# f1_score_micro                                      [0.7034901365705615]
# f1_score_macro                                      [0.5993322650403721]
# norm_macro_recall                                   [0.5476838808032647]
# AUC_macro                                           [0.8649612760652556]
# accuracy                                            [0.7034901365705615]
# balanced_accuracy                                   [0.7738419404016323]
# average_precision_score_weighted                    [0.9223088701161178]
# average_precision_score_macro                        [0.718155296736964]
# precision_score_macro                               [0.6158085571241345]
# precision_score_micro                               [0.7034901365705615]
# log_loss                                            [0.5118282417129926]
# average_precision_score_micro                       [0.8575241444743671]
# AUC_weighted                                        [0.8649612760652555]
# recall_score_macro                                  [0.7738419404016323]
# AUC_micro                                           [0.8422357874279556]
# recall_score_micro                                  [0.7034901365705615]
# recall_score_weighted                               [0.7034901365705615]
# precision_score_weighted                            [0.8950137858221593]
# weighted_accuracy                                   [0.6860236866634007]
# matthews_correlation                                [0.3561642317694817]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_3  \
# f1_score_weighted                                  [0.8585748970301323]
# f1_score_micro                                     [0.8336874051593323]
# f1_score_macro                                     [0.7208317872603587]
# norm_macro_recall                                  [0.7108782673609375]
# AUC_macro                                          [0.9183055569448382]
# accuracy                                           [0.8336874051593324]
# balanced_accuracy                                  [0.8554391336804688]
# average_precision_score_weighted                   [0.9370963241475391]
# average_precision_score_macro                      [0.7567972658968186]
# precision_score_macro                              [0.6874235684592183]
# precision_score_micro                              [0.8336874051593324]
# log_loss                                          [0.42375528555703884]
# average_precision_score_micro                      [0.8651678107057517]
# AUC_weighted                                       [0.9183055569448382]
# recall_score_macro                                 [0.8554391336804688]
# AUC_micro                                          [0.8925547283901437]
# recall_score_micro                                 [0.8336874051593324]
# recall_score_weighted                              [0.8336874051593324]
# precision_score_weighted                           [0.9164478369480067]
# weighted_accuracy                                  [0.8282870393418351]
# matthews_correlation                               [0.5162079844576082]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_9  \
# f1_score_weighted                                  [0.8757913584001227]
# f1_score_micro                                     [0.8992412746585736]
# f1_score_macro                                       [0.63401137504182]
# norm_macro_recall                                 [0.19973807393576326]
# AUC_macro                                          [0.9150953881377502]
# accuracy                                           [0.8992412746585736]
# balanced_accuracy                                  [0.5998690369678816]
# average_precision_score_weighted                   [0.9391671482289576]
# average_precision_score_macro                      [0.7702067295993593]
# precision_score_macro                              [0.7807626010925548]
# precision_score_micro                              [0.8992412746585736]
# log_loss                                           [0.2609163254994434]
# average_precision_score_micro                      [0.9715014527055117]
# AUC_weighted                                         [0.91509538813775]
# recall_score_macro                                 [0.5998690369678816]
# AUC_micro                                          [0.9715717703514544]
# recall_score_micro                                 [0.8992412746585736]
# recall_score_weighted                              [0.8992412746585736]
# precision_score_weighted                           [0.8799928560248542]
# weighted_accuracy                                  [0.9735673033951636]
# matthews_correlation                              [0.33489992886061326]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_25  \
# f1_score_weighted                                   [0.8932529870585268]
# f1_score_micro                                      [0.9065250379362669]
# f1_score_macro                                      [0.7004312024313583]
# norm_macro_recall                                  [0.32161705075697355]
# AUC_macro                                           [0.9230430103344096]
# accuracy                                             [0.906525037936267]
# balanced_accuracy                                   [0.6608085253784868]
# average_precision_score_weighted                    [0.9422752255464003]
# average_precision_score_macro                       [0.7776048420306876]
# precision_score_macro                               [0.7900084518428692]
# precision_score_micro                                [0.906525037936267]
# log_loss                                           [0.21046892934872094]
# average_precision_score_micro                       [0.9749534091641618]
# AUC_weighted                                        [0.9230430103344095]
# recall_score_macro                                  [0.6608085253784868]
# AUC_micro                                           [0.9737896891643889]
# recall_score_micro                                   [0.906525037936267]
# recall_score_weighted                                [0.906525037936267]
# precision_score_weighted                            [0.8924260904268563]
# weighted_accuracy                                   [0.9675298014851621]
# matthews_correlation                               [0.43190661716695067]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_26  ...  \
# f1_score_weighted                                   [0.8922212808312255]  ...
# f1_score_micro                                      [0.9025796661608497]  ...
# f1_score_macro                                      [0.7043745341088892]  ...
# norm_macro_recall                                    [0.343225024868157]  ...
# AUC_macro                                           [0.9214397783075575]  ...
# accuracy                                            [0.9025796661608497]  ...
# balanced_accuracy                                   [0.6716125124340785]  ...
# average_precision_score_weighted                    [0.9380411317093148]  ...
# average_precision_score_macro                        [0.762608022258366]  ...
# precision_score_macro                               [0.7649726288332503]  ...
# precision_score_micro                               [0.9025796661608497]  ...
# log_loss                                           [0.22555042115503365]  ...
# average_precision_score_micro                       [0.9675460948433308]  ...
# AUC_weighted                                        [0.9214397783075575]  ...
# recall_score_macro                                  [0.6716125124340785]  ...
# AUC_micro                                           [0.9698732387555523]  ...
# recall_score_micro                                  [0.9025796661608497]  ...
# recall_score_weighted                               [0.9025796661608497]  ...
# precision_score_weighted                            [0.8889110559014688]  ...
# weighted_accuracy                                    [0.959922562875411]  ...
# matthews_correlation                               [0.42648619466677545]  ...
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_29  \
# f1_score_weighted                                    [0.904163966769112]
# f1_score_micro                                      [0.9065250379362669]
# f1_score_macro                                      [0.7532324924087248]
# norm_macro_recall                                   [0.4826589755986417]
# AUC_macro                                           [0.9411963019151723]
# accuracy                                             [0.906525037936267]
# balanced_accuracy                                   [0.7413294877993208]
# average_precision_score_weighted                    [0.9512796793646534]
# average_precision_score_macro                       [0.8085577541137163]
# precision_score_macro                               [0.7670201493317375]
# precision_score_micro                                [0.906525037936267]
# log_loss                                           [0.18331567518136963]
# average_precision_score_micro                       [0.9793590203488491]
# AUC_weighted                                        [0.9411963019151723]
# recall_score_macro                                  [0.7413294877993208]
# AUC_micro                                           [0.9783323700553328]
# recall_score_micro                                   [0.906525037936267]
# recall_score_weighted                                [0.906525037936267]
# precision_score_weighted                            [0.9022928077169412]
# weighted_accuracy                                   [0.9475386245712485]
# matthews_correlation                                [0.5077000526701819]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_36  \
# f1_score_weighted                                   [0.9085375444431306]
# f1_score_micro                                      [0.9122913505311078]
# f1_score_macro                                      [0.7608685880283999]
# norm_macro_recall                                     [0.48204769129031]
# AUC_macro                                           [0.9434932490131465]
# accuracy                                            [0.9122913505311078]
# balanced_accuracy                                    [0.741023845645155]
# average_precision_score_weighted                    [0.9534103718033303]
# average_precision_score_macro                        [0.816981069236323]
# precision_score_macro                               [0.7862007073853139]
# precision_score_micro                               [0.9122913505311078]
# log_loss                                           [0.18297145197241096]
# average_precision_score_micro                        [0.980212844977179]
# AUC_weighted                                        [0.9434932490131465]
# recall_score_macro                                   [0.741023845645155]
# AUC_micro                                           [0.9792316035009591]
# recall_score_micro                                  [0.9122913505311078]
# recall_score_weighted                               [0.9122913505311078]
# precision_score_weighted                            [0.9061909472527478]
# weighted_accuracy                                   [0.9548124392866707]
# matthews_correlation                                [0.5252854276310054]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_14  \
# f1_score_weighted                                   [0.8353395018439429]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# norm_macro_recall                                                  [0.0]
# AUC_macro                                           [0.8902837285379004]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# average_precision_score_weighted                    [0.9236051436888403]
# average_precision_score_macro                       [0.7121661502609211]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# log_loss                                           [0.25090816560453605]
# average_precision_score_micro                       [0.9663312639929988]
# AUC_weighted                                        [0.8902837285379005]
# recall_score_macro                                                 [0.5]
# AUC_micro                                           [0.9656369032953318]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# weighted_accuracy                                   [0.9843450583187134]
# matthews_correlation                                               [0.0]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_23  \
# f1_score_weighted                                   [0.8725173519760403]
# f1_score_micro                                      [0.8998482549317147]
# f1_score_macro                                      [0.6174621736634132]
# norm_macro_recall                                   [0.1720024377277265]
# AUC_macro                                           [0.8785567947955624]
# accuracy                                            [0.8998482549317147]
# balanced_accuracy                                   [0.5860012188638632]
# average_precision_score_weighted                    [0.9259899677020644]
# average_precision_score_macro                       [0.7298175659137285]
# precision_score_macro                               [0.8054440789473685]
# precision_score_micro                               [0.8998482549317147]
# log_loss                                            [0.2585799476917954]
# average_precision_score_micro                        [0.964677740005733]
# AUC_weighted                                        [0.8785567947955624]
# recall_score_macro                                  [0.5860012188638632]
# AUC_micro                                            [0.963656066003348]
# recall_score_micro                                  [0.8998482549317147]
# recall_score_weighted                               [0.8998482549317147]
# precision_score_weighted                            [0.8831869059979235]
# weighted_accuracy                                   [0.9777679845686824]
# matthews_correlation                                [0.3241515885151499]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_43  \
# f1_score_weighted                                   [0.8353395018439429]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# norm_macro_recall                                                  [0.0]
# AUC_macro                                           [0.9467636200627214]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# average_precision_score_weighted                    [0.9549714448557579]
# average_precision_score_macro                       [0.8224714637241195]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# log_loss                                            [0.3446707232980666]
# average_precision_score_micro                       [0.9780810328751199]
# AUC_weighted                                        [0.9467636200627215]
# recall_score_macro                                                 [0.5]
# AUC_micro                                           [0.9768703673428035]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# weighted_accuracy                                   [0.9843450583187134]
# matthews_correlation                                               [0.0]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_7  \
# f1_score_weighted                                  [0.8744969686226501]
# f1_score_micro                                     [0.8971168437025797]
# f1_score_macro                                     [0.6324926984160407]
# norm_macro_recall                                 [0.19971399303876836]
# AUC_macro                                          [0.9232699264791691]
# accuracy                                           [0.8971168437025797]
# balanced_accuracy                                  [0.5998569965193842]
# average_precision_score_weighted                    [0.937550123367585]
# average_precision_score_macro                      [0.7557161254331243]
# precision_score_macro                              [0.7620366994774578]
# precision_score_micro                              [0.8971168437025797]
# log_loss                                           [0.2325061832520065]
# average_precision_score_micro                       [0.969356691349942]
# AUC_weighted                                       [0.9232699264791691]
# recall_score_macro                                 [0.5998569965193842]
# AUC_micro                                          [0.9707443797909648]
# recall_score_micro                                 [0.8971168437025797]
# recall_score_weighted                              [0.8971168437025797]
# precision_score_weighted                           [0.8758422773303859]
# weighted_accuracy                                  [0.9709184230153547]
# matthews_correlation                              [0.32351938295979377]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_15  \
# f1_score_weighted                                    [0.875405251100669]
# f1_score_micro                                      [0.8968133535660091]
# f1_score_macro                                       [0.637402998909911]
# norm_macro_recall                                   [0.2088452839415611]
# AUC_macro                                           [0.9165031944236053]
# accuracy                                            [0.8968133535660091]
# balanced_accuracy                                   [0.6044226419707805]
# average_precision_score_weighted                    [0.9371334419742199]
# average_precision_score_macro                       [0.7571907785724261]
# precision_score_macro                               [0.7570061821265421]
# precision_score_micro                               [0.8968133535660091]
# log_loss                                           [0.21467417276351283]
# average_precision_score_micro                        [0.972804088531048]
# AUC_weighted                                        [0.9165031944236051]
# recall_score_macro                                  [0.6044226419707805]
# AUC_micro                                           [0.9714396899703188]
# recall_score_micro                                  [0.8968133535660091]
# recall_score_weighted                               [0.8968133535660091]
# precision_score_weighted                            [0.8754970463528322]
# weighted_accuracy                                    [0.969406058220181]
# matthews_correlation                               [0.32764166121222826]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_2  \
# f1_score_weighted                                  [0.8366610725508761]
# f1_score_micro                                     [0.8883156297420334]
# f1_score_macro                                     [0.4757848355623805]
# norm_macro_recall                                [0.005078290700883725]
# AUC_macro                                          [0.8986578604678733]
# accuracy                                           [0.8883156297420334]
# balanced_accuracy                                  [0.5025391453504419]
# average_precision_score_weighted                    [0.931796527431214]
# average_precision_score_macro                      [0.7481270747833388]
# precision_score_macro                              [0.7775921425678411]
# precision_score_micro                              [0.8883156297420334]
# log_loss                                          [0.24489207047439188]
# average_precision_score_micro                      [0.9675991033575477]
# AUC_weighted                                       [0.8986578604678733]
# recall_score_macro                                 [0.5025391453504419]
# AUC_micro                                          [0.9673043950806045]
# recall_score_micro                                 [0.8883156297420334]
# recall_score_weighted                              [0.8883156297420334]
# precision_score_weighted                           [0.8636730050501791]
# weighted_accuracy                                  [0.9840934957391301]
# matthews_correlation                             [0.053097901959317934]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_17  \
# f1_score_weighted                                   [0.8874281036766141]
# f1_score_micro                                      [0.8977238239757208]
# f1_score_macro                                      [0.6924195347520512]
# norm_macro_recall                                   [0.3259154908705615]
# AUC_macro                                           [0.9063003036045398]
# accuracy                                            [0.8977238239757208]
# balanced_accuracy                                   [0.6629577454352807]
# average_precision_score_weighted                    [0.9340009655305633]
# average_precision_score_macro                       [0.7495431762838726]
# precision_score_macro                               [0.7456385405585013]
# precision_score_micro                               [0.8977238239757208]
# log_loss                                           [0.23413993412899087]
# average_precision_score_micro                       [0.9686837098182907]
# AUC_weighted                                        [0.9063003036045398]
# recall_score_macro                                  [0.6629577454352807]
# AUC_micro                                           [0.9682553001397712]
# recall_score_micro                                  [0.8977238239757208]
# recall_score_weighted                               [0.8977238239757208]
# precision_score_weighted                            [0.8831985227650206]
# weighted_accuracy                                   [0.9560098909623385]
# matthews_correlation                               [0.40014348807109756]
#
#                                  790bdf3f-6cde-4992-babe-0f0b16f9fb95_31
# f1_score_weighted                                   [0.9100415644605403]
# f1_score_micro                                      [0.9128983308042489]
# f1_score_macro                                      [0.7668111420906795]
# norm_macro_recall                                   [0.5016773270945287]
# AUC_macro                                           [0.9448491887516277]
# accuracy                                            [0.9128983308042489]
# balanced_accuracy                                   [0.7508386635472644]
# average_precision_score_weighted                    [0.9516860732237478]
# average_precision_score_macro                       [0.8085204474402641]
# precision_score_macro                               [0.7860811293290488]
# precision_score_micro                               [0.9128983308042489]
# log_loss                                           [0.18115151864375498]
# average_precision_score_micro                        [0.980352027134298]
# AUC_weighted                                        [0.9448491887516278]
# recall_score_macro                                  [0.7508386635472644]
# AUC_micro                                           [0.9793693944704005]
# recall_score_micro                                  [0.9128983308042489]
# recall_score_weighted                               [0.9128983308042489]
# precision_score_weighted                            [0.9080335867085474]
# weighted_accuracy                                   [0.9531333625443325]
# matthews_correlation                                [0.5357619178216784]
#
# [21 rows x 42 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/790bdf3f-6cde-4992-babe-0f0b16f9fb95/model_data
# Downloaded azureml/790bdf3f-6cde-4992-babe-0f0b16f9fb95/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                                                                    n_estimators=10,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=False,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3076923076923077,
#                                                                                          0.3076923076923077,
#                                                                                          0.07692307692307693,
#                                                                                          0.15384615384615385,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('24',
#                                              Pipeline(memory=None,
#                                                       steps=[('sparsenormalizer',
#                                                               <azureml.automl.runtime.shared.model_wrappers.SparseNormalizer object at 0x7eff6b0029b0>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=0.7,
#                                                                                 eta=0.5,
#                                                                                 g...
#                                                                                    min_impurity_split=None,
#                                                                                    min_samples_leaf=0.035789473684210524,
#                                                                                    min_samples_split=0.01,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=10,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=False,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.3076923076923077, 0.3076923076923077,
#                                          0.07692307692307693, 0.15384615384615385,
#                                          0.07692307692307693,
#                                          0.07692307692307693]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_c934bf3c_2bc0_11eb_8109_000d3aef5449row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_c934bf3c_2bc0_11eb_8109_000d3aef5449row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c934bf3c_2bc0_11eb_8109_000d3aef5449row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c934bf3c_2bc0_11eb_8109_000d3aef5449row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449row0_col0" class="data row0 col0" >28868</td>
#                         <td id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449row0_col1" class="data row0 col1" >390</td>
#             </tr>
#             <tr>
#                         <th id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449row1_col0" class="data row1 col0" >1079</td>
#                         <td id="T_c934bf3c_2bc0_11eb_8109_000d3aef5449row1_col1" class="data row1 col1" >2613</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: f58bb030-5656-4fa5-b9fe-d72f62502149,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/ef22e2eb-a072-4db6-86df-7ea6643b1b5f/resourceGroups/aml-quickstarts-127085/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-127085/PipelineRuns/PipelineSubmit/f58bb030-5656-4fa5-b9fe-d72f62502149)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  726fe86d-aa66-490f-bcb6-4c385f911dd3

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
